# %%
a = input("enter a name to check palindrome:")
b = a[::-1]

if a==b:
        print("given word is palindrome")
else :
        print("given word is not palindrome")
# Out:
# given word is not palindrome

# %%
a = int(input("enter a number for addition : "))
b = int(input("enter a number for add in 1st number: "))

print(f"{a} + {b} = {a+b}")
# Out:
# 5 + 5 = 10

# %%
for i in range(5):
    print()
    for j in range(i+1):
        print("*", end="")
# Out:
# *
# **
# ***
# ****
# *****

# %%
customers = [101, 102, 103, 104]
customers.append(105)

# %%
customers.remove(102)

# %%
customers
# Out:
# [101, 103, 104, 105]

# %%
customers.pop(1)
# Out:
# 103

# %%
customers
# Out:
# [101, 104, 105]

# %%
name = ["nirav" , "tanay" , "devanchsidsf" , "dehuvbj" , "loram"]
a =""
for i in name:
    if len(a)<len(i):
        a = i
print(a)
# Out:
# devanchsidsf
