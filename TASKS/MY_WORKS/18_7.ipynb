# %% [markdown]
# # function

# %% [markdown]
# # block of code when you want to use that code

# %%
def demo():
    print("hello everyone")

# %%
demo()
# Out:
# hello everyone

# %%
def nirav():
    print("here is nirav")

# %%
nirav()
# Out:
# here is nirav

# %%
def tops(name):
    print("hellow" , name)

# %%
tops("nirav")
# Out:
# hellow nirav

# %%
def tops2(name, age):
    print(f"hellow my name is {name} and my age is {age}")

# %%
tops2("nirav" , 19)
# Out:
# hellow my name is nirav and my age is 19

# %%
def add(a,b):
    print(a+b)

# %%
add(56,5)
# Out:
# 61

# %%
def mult(a,b):
    print(a*b)

# %%
mult(45,2)
# Out:
# 90

# %%
def tops3(name="nirav"):
    print("hellow" , name)

# %%
tops3()
# Out:
# hellow nirav

# %%
def multi1(a,b):
    c = a*b
    return c

# %%
def multi1(a,b):
    c = a*b
    return c

# %%
multi1(4,2)+69
# Out:
# 77

# %%
# calculator = price and rate

def calc(a,b):
    disc = a*b/100
    final_price = a-disc


    return final_price

# %%
calc(10000,20)
# Out:
# 8000.0

# %%
def incriment(salary,incriment):
    incri = salary*incriment/100
    final_salary = salary+incri

    return final_salary

# %%
incriment(10000,20)
# Out:
# 12000.0

# %%
def xyz(num):
    if num%2==0:
        print("even")
    else:
        print("odd")

# %%
xyz(2)
# Out:
# even
