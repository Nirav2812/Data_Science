# %%
#conditions
# if contition:
        #code
# Out:
# hello

# %%
a = int(input("enter rantom number"))
if a<45:
    print("take it")
    print("gulee")

print("hello")
# Out:
# hello

# %%
a = int(input("enter rantom number"))
if a<45:
    print("take it")
    print("gulee")
else:
    print("dont take it")
# Out:
# dont take it

# %%
a = int(input("what is your age ; "))
if a>18:
    print(f"you can drive cz your age is {a}")
else:
    print(f"you can not drive , you are bachcha and your age is {a}")
# Out:
# you can drive cz your age is 45

# %%
marks = int(input("enter your marks to know your grade : "))
if marks>90:
    print("your grade is A")
elif marks>80:
    print("your grade is B")
elif marks>60:
    print("your grade is C")
elif marks>40:
    print("your grade is D")
else:
    print("SORRY , you are fail")
# Out:
# your grade is A

# %% [markdown]
# # nested if

# %%
a = int(input("what is your age ; "))
b = input("you have license? (yes/no)= ")
if a>18:
    #print(f"you can drive cz your age is {a}")
    if b == ("yes"):
        print(f"you can drive because your age is {a} and you have licence")
    else:
        print("you need license")
else:
    print(f"you can not drive , you are bachcha and your age is {a}")
# Out:
# you can drive because your age is 45 and you have licence

# %%
bill = int(input("how much is your bill = "))
if bill>5000:
    print(f"your bill is {bill} and you got 20% discount")
else:
    print(f"your bill is {bill} and you got 10% discount")
# Out:
# your bill is 5000 and you got 10% discount

# %%
a = int(input("input a"))
b = int(input("input b"))
c = int(input("input c"))

if a > b and a > c:
    print("a is the largest number")
elif b > a and b>c:
    print("b is the largest number")
else:
    print("c is the largest number")
# Out:
# a is the largest number

# %%
a = int(input("add a number"))

if a%2==0:
    print(f"{a} is even")
else:
    print(f"{a} is odd")
# Out:
# 45 is off

# %%
sale = int(input("whats your sale mr.employee = "))
b = int(input("how much your attandence (1=100)"))
if sale>=100000:
    if b>=90:
        print("you got bonus")
    else:
        print("you have to full fill your attendence above 90")
else:
    print("you are not alligable to get bonus")
# Out:
# you got bonus

# %%
a = int(input("whats your age = "))
b = input("from which country you are (india/.....)")

if a>=18:
    if b == ("india"):
        print(f"your age is {a} " \
        f"and you are citizon of {b} " \
        "so you can vote")
    else:
        print("you are not indian")
else:
    print(f"you can not vote because your age is {a} and you are citizon of {b}")
# Out:
# your age is 69 and you are citizon of india so you can vote
