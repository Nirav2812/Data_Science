# %% [markdown]
# # 1

# %% [markdown]
# # List - ordered , mutable , [] , allow multi data types

# %%
students = ["nirav" , "tanay" , 4500 , 78.56 , True , 5+7j , [ "sduh" , "bfufbds" , "fbrfds"] , (1,2,3) , 45000]

# %%
students[2]
# Out:
# 4500

# %%
# i want to change 3rd place 4500 to 50000
students[2] = 5000

# %%
students[2:8]
# Out:
# [5000, 78.56, True, (5+7j), ['sduh', 'bfufbds', 'fbrfds'], (1, 2, 3)]

# %%
# add something in last
students.append(65000)

# %%
# pop
students.pop()
# Out:
# 65000

# %%
students
# Out:
# ['nirav',
#  'tanay',
#  5000,
#  78.56,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000]

# %%
l = [5,8,3,2,1,4,8,2]
a = sorted(l)
print(a)
# Out:
# [1, 2, 2, 3, 4, 5, 8, 8]

# %%
students.extend(["nirav"])

# %%
students
# Out:
# ['nirav',
#  'tanay',
#  5000,
#  78.56,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000,
#  'nirav']

# %%
students.insert(0, "Aaru")

# %%
students
# Out:
# ['Aaru',
#  'nirav',
#  'tanay',
#  5000,
#  78.56,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000,
#  'nirav']

# %%
students.insert(2, "princy")

# %%
students
# Out:
# ['Aaru',
#  'nirav',
#  'princy',
#  'tanay',
#  5000,
#  78.56,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000,
#  'nirav']

# %%
students.insert(20, "kuchupuchu")

# %%
students
# Out:
# ['Aaru',
#  'nirav',
#  'princy',
#  'tanay',
#  5000,
#  78.56,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000,
#  'nirav',
#  'kuchupuchu']

# %%
students.insert(15,"muchukuchu")

# %%
students
# Out:
# ['Aaru',
#  'nirav',
#  'princy',
#  'tanay',
#  5000,
#  78.56,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000,
#  'nirav',
#  'kuchupuchu',
#  'muchukuchu']

# %%
del students[5]

# %%
students
# Out:
# ['Aaru',
#  'nirav',
#  'princy',
#  'tanay',
#  5000,
#  True,
#  (5+7j),
#  ['sduh', 'bfufbds', 'fbrfds'],
#  (1, 2, 3),
#  45000,
#  'nirav',
#  'kuchupuchu',
#  'muchukuchu']

# %%
tup = (2,"nirav" , "tanay" , 59.2)

# %%
type(tup)
# Out:
# tuple

# %%
(a,b)=(2,5)

# %%
a
# Out:
# 2

# %%
type(a)
# Out:
# int

# %%
# set= {}
xyz = {}
type(xyz)
# Out:
# dict

# %%
ab = { "nirav" , "tanay" , 54.2 , 48.6}
print(ab)
# Out:
# {48.6, 'nirav', 'tanay', 54.2}

# %%
ab.add(8484)

# %%
ab
# Out:
# {48.6, 54.2, 8484, 'nirav', 'tanay'}

# %%
ab
# Out:
# {48.6, 54.2, 8484, 'nirav', 'tanay'}
