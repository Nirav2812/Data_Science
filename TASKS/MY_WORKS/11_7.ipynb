# %%
#one time comment 
#python 


'''gaefuhfeihdedhsaih
feihidh'''
# Out:
# 'gaefuhfeihdedhsaih\nfeihidh'

# %% [markdown]
# this is python
# heloww

# %%
print("hello world")
# Out:
# hello world

# %%
# python
# hig level , object oriented , interpreted , dynamic programming language 
# case sensitive language

# %%
# variables (store data in memory) store the value
a = 3
b = 8
tops = "data science"

print(a)
# Out:
# 3

# %%
print(a)
# Out:
# 3

# %%
student_id = 123

# %%
# datatypes 
a = "nirav"                 #string
b = 56                      #integer
c = 5.6                     #float
d = True                   #boolean         


type(a)
type(b)
type(c) 
type(d)

# %%
e = 5 + 6j           # 5=i = real , 6j = imaginorr    #complex number
type(e)
# Out:
# complex

# %%
student = "nirav"

# %%
print("hello world")
# Out:
# hello world

# %%
a = "hello"
a1 = a.upper()
a2 = a1.lower()
a3 = a1.capitalize()
a4 = a1.title()


b = "nirav panchal" 
b1 = b.title()

b.replace( "nirav","nirav panchal")

# %%
#formating strings
name = input("enter your name : ")
print(name)
# Out:
# tanay

# %%
print(f'hellow {name} welcome to tops technology')
# Out:
# hellow tanay welcome to tops technology

# %%
#list
l = [1,2.5,3,"nirav"]
l
type(l)
# Out:
# list

# %%
l.append(5)
l
# Out:
# [1, 2.5, 3, 'nirav', 5]

# %%
l.insert(2, 85)
l
# Out:
# [1, 2.5, 85, 85, 3, 'nirav', 5]

# %%
#tupple
t = (1,2.5,3,"nirav")
t 
type(t)
