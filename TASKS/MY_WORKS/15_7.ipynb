# %%
#dict - keyValue

# %%
# d1 = {"key":"value"}
d1 = {"name":"nirav"}

# %%
type(d1)
# Out:
# dict

# %%
d2 = {
    "name": "nirav",
    "email": "niravpanchal@gmail.com",
    "phone_no": "7600449035"
}

# %%
d2
# Out:
# {'name': 'nirav', 'email': 'niravpanchal@gmail.com', 'phone_no': '7600449035'}

# %%
d2["email"]
# Out:
# 'niravpanchal@gmail.com'

# %%
d2["email"] = "niravpanchal22@gmail.com"

# %%
d2
# Out:
# {'name': 'nirav',
#  'email': 'niravpanchal22@gmail.com',
#  'phone_no': '7600449035'}

# %%
dict = {
    "company":"Tops",
    "cources":["data_scients" , "data_Analytics" , "python"],
    "students":"23"
}

# %%
dict["cources"]
# Out:
# ['data_scients', 'data_Analytics', 'python']

# %%
dict["cources"][1]
# Out:
# 'data_Analytics'

# %%
dict.pop("students")
# Out:
# '23'

# %%
dict.keys()
# Out:
# dict_keys(['company', 'cources'])

# %%
dict.values()
# Out:
# dict_values(['Tops', ['data_scients', 'data_Analytics', 'python']])

# %%
nirav_dict = {
    "name":"nirav",
    "email":"niravpanchal322@gmail.com",
    "mobile_no":"7600449035",
    "frined":["tanya","het",]
}

# %%
nirav_dict
# Out:
# {'name': 'nirav',
#  'email': 'niravpanchal322@gmail.com',
#  'mobile_no': '7600449035',
#  'frined': ['tanya', 'het']}

# %%
nirav_dict["name"]
# Out:
# 'nirav'

# %%
nirav_dict["frined"].remove("het")

# %%
nirav_dict
# Out:
# {'name': 'nirav',
#  'email': 'niravpanchal322@gmail.com',
#  'mobile_no': '7600449035',
#  'frined': ['tanya']}

# %%
nirav_dict.items()
# Out:
# dict_items([('name', 'nirav'), ('email', 'niravpanchal322@gmail.com'), ('mobile_no', '7600449035'), ('frined', ['tanya'])])

# %%
nirav_dict.fromkeys("brothers")
# Out:
# {'b': None, 'r': None, 'o': None, 't': None, 'h': None, 'e': None, 's': None}

# %%
nirav_dict
# Out:
# {'name': 'nirav',
#  'email': 'niravpanchal322@gmail.com',
#  'mobile_no': '7600449035',
#  'frined': ['tanya']}

# %%
nirav_dict
