# %%
# oops - object oriented programing system

# class - blue print for creating object
# objects - car is a class and engine parts are object 
# intace of class with its own data
# attribute - is variable for storing an object's data
# method - to define functions class ni andar na function ne method kevay
# self - refers to current object instant
# _init_() - special constructor method that initialized object attributes
#            when object is created

# %%
a = 1

print(type(a))
# Out:
# <class 'int'>

# %%
print(type("nirav"))
# Out:
# <class 'str'>

# %%
class Test:
    pass

# %%
b = Test()
type(b)
# Out:
# __main__.Test

# %%
class Tops:
    def wlcm_msg(self):
        print("welcome he jiii")

c = Tops
c.wlcm_msg()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       2     def wlcm_msg(self):
#       3         print("welcome he jiii")
#       4
#       5 c = Tops
# ----> 6 c.wlcm_msg()
#       7
#
# TypeError: Tops.wlcm_msg() missing 1 required positional argument: 'self'

# %%
class Tops:
    def wlcm_msg(self):
        print("welcome he jiii")

C = Tops()
C.wlcm_msg()
# Out:
# welcome he jiii

# %%
class Student:
    # self - which object am i working with 
    def __init__(self):
        self.name = "rahul"
    def display(self):
        print("name = " , self.name)

# %%
s = Student()
s.display()
# Out:
# name =  rahul

# %%
class Studentsss:
    pass
s = Studentsss()
s.name = "nirav"

# %%
# constructor with parameter

# %%
a = Vidhyarth()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 a = Vidhyarth()
#
# TypeError: Vidhyarth.__init__() missing 2 required positional arguments: 'name' and 'age'
