# %% [markdown]
# # TASK 1

# %%
a = int(input("how much time you are listning music(in minutes) : "))
if a > 120:
    print("you are great music fan!")
else:
    print("keep listning")
# Out:
# keep listning

# %% [markdown]
# # TASK 2

# %%
a = int(input("what is your order ammount"))
if a > 300:
    print(f"congrats!! your total value of order is {a} thats why you got free delivery")
else:
    print("your total value of order is not below 300.  if you want free delivery let me sudgest you more items for your daily usage")
# Out:
# your total value of order is not below 300.  if you want free delivery let me sudgest you more items for your daily usage

# %% [markdown]
# # TASK 3

# %%
a = int(input("whats your total cart ammount : "))
if a >2000:
    print(f"your total cart value is {a} so you got 10% discount")
elif a >1000:
    print(f"your total cart value is {a} so you got 5% discount")
else:
    print(f"your total cart value is {a} if you want discount lets full fill your house with more items")
# Out:
# your total cart value is 20 if you want discount lets full fill your house with more items

# %% [markdown]
# # TASK 4

# %%
a = int(input("enter their IPL fantasy team points"))
if a > 800:
    print("champoinsss!!!")
else:
    if a >= 500:
        print("top performarcee!!")
    else:
        print("keep going!")
# Out:
# champoinsss!!!
