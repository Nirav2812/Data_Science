# %% [markdown]
# # TASK 1

# %%
songs = ["shape of you",
         "despacito",
         "channa mereyaa",
         "gungam style",
         "tota bole tee tee teeee"]
with open ("playlist.txt" , "w") as file:
    for song in songs:
        file.write(song + "\n")

print("successfulllllly printed your playlist bradahhhh")
# Out:
# successfulllllly printed your playlist bradahhhh

# %% [markdown]
# # TASK 2

# %%
with open ("playlist.txt" , "r") as file:
    for song in songs:
        print(song )
# Out:
# shape of you
# despacito
# channa mereyaa
# gungam style
# tota bole tee tee teeee

# %% [markdown]
# # TASK 3

# %%
import csv

with open("data.csv", "r") as file:
    reader = csv.DictReader(file)

    for match in reader:
        print("in", match["season"], "match between" , match["team1"] , "and" , match["team2"] , "and the winner is ", match["winner"])
# Out:
# in 2008 match between Kolkata Knight Riders and Royal Challengers Bangalore and the winner is  Kolkata Knight Riders
# in 2008 match between Chennai Super Kings and Kings XI Punjab and the winner is  Chennai Super Kings
# in 2008 match between Rajasthan Royals and Delhi Daredevils and the winner is  Delhi Daredevils
# in 2008 match between Mumbai Indians and Royal Challengers Bangalore and the winner is  Royal Challengers Bangalore
# in 2008 match between Deccan Chargers and Kolkata Knight Riders and the winner is  Kolkata Knight Riders
# in 2008 match between Kings XI Punjab and Rajasthan Royals and the winner is  Rajasthan Royals
# in 2008 match between Deccan Chargers and Delhi Daredevils and the winner is  Delhi Daredevils
# in 2008 match between Chennai Super Kings and Mumbai Indians and the winner is  Chennai Super Kings
# in 2008 match between Deccan Chargers and Rajasthan Royals and the winner is  Rajasthan Royals
# ...

# %% [markdown]
# # TASK 4

# %%
import json

with open("Film.json", "r") as file:
    movies = json.load(file)

for movie in movies:
    print("Title:", movie["Title"])
    print("Rating:", movie["imdbRating"])
    print()
# Out:
# Title: Avatar
# Rating: 7.9
#
# Title: I Am Legend
# Rating: 7.2
#
# Title: 300
# Rating: 7.7
#
# Title: The Avengers
# Rating: 8.1
#
# Title: The Wolf of Wall Street
# Rating: 8.2
#
# Title: Interstellar
# Rating: 8.6
#
# Title: Game of Thrones
# Rating: 9.5
#
# Title: Vikings
# Rating: 8.6
#
# Title: Gotham
# Rating: 8.0
#
# Title: Power
# Rating: 8.0
#
# Title: Narcos
# Rating: 8.9
#
# Title: Breaking Bad
# Rating: 9.5
#
# Title: Doctor Strange
# Rating: N/A
#
# Title: Rogue One: A Star Wars Story
# Rating: N/A
#
# Title: Assassin's Creed
# Rating: N/A
#
# Title: Luke Cage
# Rating: N/A

# %% [markdown]
# # TASK 5

# %%
from pathlib import Path
import json

file_path = Path("my_fav_apps.json")

if not file_path.exists():
    apps = [
        {"name": "Instagram", "category": "Social Media"},
        {"name": "Zomato", "category": "Food Delivery"},
        {"name": "Paytm", "category": "Finance"}
    ]

    with open(file_path, "w") as file:
        json.dump(apps, file, indent=4)

    print("File created successfully!")
else:
    print("File already exists!")
