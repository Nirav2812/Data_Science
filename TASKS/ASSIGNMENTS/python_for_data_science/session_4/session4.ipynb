# %% [markdown]
# # TASK 1

# %%
str = "Flipkart-Sale2024"
a = str.lower()
a = a.replace("-", " ")
print(a)
# Out:
# flipkart sale2024

# %% [markdown]
# # TASK 2

# %%
product_name = "         Oneplus Nord-CE 3 "

cln = product_name.strip()
cln = cln.replace("-", "/")
cln = cln.upper()
print(cln)
# Out:
# ONEPLUS NORD/CE 3

# %% [markdown]
# # TASK 3

# %%
split_product_code = "ZOMATO@2026@YUHU"
split = split_product_code.split("@")
print(split)
# Out:
# ['ZOMATO', '2026', 'YUHU']

# %% [markdown]
# # TASK 4

# %%
spotify = "Spotify_Premium_Offer"
spotufy_sliced = spotify[8:15:]
print(spotufy_sliced)
# Out:
# Premium

# %% [markdown]
# # TASK 5

# %%
product_name = "Myntra Shirt"
price = 250
print(f"name of product is  {product_name} and its price is  {price}")
# Out:
# name of product is  Myntra Shirt and its price is  250
