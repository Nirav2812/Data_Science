# %%
price = 1250
delivery_fee = 300
discount = 100
#printing the price, delivery fee, discount and total cost
print("price is = ", price)
print("delivery fee is = ", delivery_fee)
print("discount is = ", discount)
print("total cost is = ", price + delivery_fee - discount)
# Out:
# price is =  1250
# delivery fee is =  300
# discount is =  100
# total cost is =  1450

# %%
'''if price < 1000 it prints price is less than 1000
   if price > 1000 it prints price is greater than 1000'''

if price < 1000:
    print("price is less than 1000")
else :
    print("price is greater than 1000")
# Out:
# price is greater than 1000

# %%
team_name = "CSK"
scored = 246
over_played = 20
#printing the team name, total score and over played
print("Team name = ", team_name)
print("Total score = ", scored)
print("Over played = ", over_played)
# Out:
# Team name =  CSK
# Total score =  246
# Over played =  20
