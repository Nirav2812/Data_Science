# %% [markdown]
# # TASK 1

# %%
my_age=21
my_height=179.2
my_name="Nirav panchal" 
my_spotify=True

print(f"my name is {my_name} , my age is {my_age} , my height is {my_height} cm and my spotify status is{my_spotify}")
# Out:
# my name is Nirav panchal , my age is 21 , my height is 179.2 cm and my spotify status isTrue

# %%
a = type(my_age)
b = type(my_height)
c = type(my_name)
d = type(my_spotify)
print(f"my age type is {a} , my height type is {b} , my name type is {c} and my spotify status type is {d}")
# Out:
# my age type is <class 'int'> , my height type is <class 'float'> , my name type is <class 'str'> and my spotify status type is <class 'bool'>

# %% [markdown]
# # TASK 2

# %%
total_cart_ammount = ['200.00' , '39.70' , '482.65']   
print(f"item 1: {float(total_cart_ammount[0])}, item 2: {float(total_cart_ammount[1])}, item 3: {float(total_cart_ammount[2])}")
print("total cart ammount is " + str(float(total_cart_ammount[0]) + float(total_cart_ammount[1]) + float(total_cart_ammount[2])))

def total_price(total_cart_ammount):
    result = sum(total_cart_ammount)
    return result
result = total_price([float(total_cart_ammount[0]) , float(total_cart_ammount[1]) , float(total_cart_ammount[2])])
# Out:
# item 1: 200.0, item 2: 39.7, item 3: 482.65
# total cart ammount is 722.3499999999999

# %% [markdown]
# # TASK 3

# %%
a = int(input("what is your score"))
int(a)
if a == 50:
    print("half century!")
elif a < 50:
    print("keep going for half century!")
elif 50 < a < 100:
    print("keep going for century!")
elif a >= 100:
    print("well century!")
else:
    print("keep going!")
# Out:
# keep going for century!

# %% [markdown]
# # TASK 4

# %%
    variable_is_premium = "True"
    a = bool(variable_is_premium)
    print(type(a))
# Out:
# <class 'bool'>
