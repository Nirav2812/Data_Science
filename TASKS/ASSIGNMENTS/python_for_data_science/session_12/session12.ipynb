# %% [markdown]
# # TASK 1

# %%
spoty_song = [ 'Shape Of You', 'Blinding Lights', 'Levitating', 'Senorita']
list(map(lambda x : x.lower() , spoty_song))
# Out:
# ['shape of you', 'blinding lights', 'levitating', 'senorita']

# %% [markdown]
# # TASK 2

# %%
rating = [4.2, 3.8, 4.5, 2.9, 3.5]
list(filter(lambda x:x>4 , rating))
# Out:
# [4.2, 4.5]

# %% [markdown]
# # TASK 3

# %%
from functools import reduce
cart = [499,1299,299,799]
reduce(lambda x,y : x+y , cart)
# Out:
# 2896

# %% [markdown]
# # TASK 4

# %%
counts = [950, 1500, 25000, 1200000]

print(list(map(lambda x: f"{x/1000000}M" if x >= 1000000 else f"{x/1000}K" if x >= 1000 else x, counts)))
# Out:
# [950, '1.5K', '25.0K', '1.2M']

# %% [markdown]
# # TASK 5

# %%
scores = [101, 98, 120, 77, 88]

print(list(filter(lambda x: x % 2 == 0, scores)))
# Out:
# [98, 120, 88]
