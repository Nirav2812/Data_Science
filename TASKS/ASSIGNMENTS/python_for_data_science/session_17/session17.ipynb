# %% [markdown]
# # TASK 1

# %%
import math
math.sqrt(225)
# Out:
# 15.0

# %% [markdown]
# # TASK 2

# %%
import os

os.makedirs("mydocument", exist_ok=True)
os.path.abspath("mydocument")
# Out:
# 'c:\\Users\\Admin\\Documents\\GitHub\\Data_Science\\TASKS\\ASSIGNMENTS\\python_for_data_science\\session_17\\mydocument'

# %% [markdown]
# # TASK 3

# %%
from datetime import datetime

current_time = datetime.now()

formatted_time = current_time.strftime("%d-%m-%Y %H:%M:%S")

print(formatted_time)
type(current_time)
# Out:
# 04-08-2026 18:15:54
# datetime.datetime

# %% [markdown]
# # TASK 4
