# %% [markdown]
# # TASK 1

# %%
playlist_ids = [18472915 , 90634182 , 51720864 , 29387541 , 76145093]
print(playlist_ids)
# Out:
# [18472915, 90634182, 51720864, 29387541, 76145093]

# %% [markdown]
# # TASK 2

# %%
playlist_ids.append(81590324)

# %%
playlist_ids.extend([78854157])

# %%
playlist_ids
# Out:
# [18472915, 90634182, 51720864, 29387541, 76145093, 81590324, 78854157]

# %% [markdown]
# # TASK 3

# %%
playlist_ids.pop()
# Out:
# 78854157

# %%
playlist_ids
# Out:
# [18472915, 90634182, 51720864, 29387541, 76145093, 81590324]

# %% [markdown]
# # TASK 4

# %%
insta_filters = ("shine" , "glow" , "bgchange" , "bgremove")

# %%
# insta_filters.insert(0 : "shine2")
#   Cell In[12], line 1
#     insta_filters.insert(0 : "shine2")
#                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# # TASK 5

# %%
zomato_cart_prices=[500,700,750,799,900,1050]
# zomato_cart_prices can change depend on the items added to the cart. So, we need to use list instade of tuple.

crick_team=("CSK","RR","GT","MI","RCB")
# cricket_team is fixed for a particular match. So, we can use tuple instead of list.
